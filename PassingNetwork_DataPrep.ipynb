# %% [markdown]
# # __INTERACTIVE PASSING NETWORK | Data Loading & Preparation__

# %% [markdown]
# _Ryan Ferrera | ryanferrera.com | Twitter: @RyanFerrera_

# %% [markdown]
# ## __SETUP__

# %%
import numpy as np
import pandas as pd
import json
import requests
import random

# %% [markdown]
# ## __DATA LOADING__

# %% [markdown]
# Adapted from a script written by Devin Pleuler:
# https://github.com/devinpleuler/analytics-handbook/blob/master/notebooks/data_extraction_and_transformation.ipynb

# %%
url = "https://raw.githubusercontent.com/statsbomb/open-data/master/data/"
comp_url = url + "matches/{}/{}.json"
match_url = url + "events/{}.json"

# %%
def get_data(competition_id, season_id):
    matches = requests.get(url=comp_url.format(competition_id, season_id)).json()
    match_ids = [m['match_id'] for m in matches]

    all_events = []
    for match_id in match_ids:

        events = requests.get(url=match_url.format(match_id)).json()

        passes = [x for x in events if x['type']['name'] == "Pass"]
        for p in passes:
            try:
                
                try:
                    outcome = p['pass']['outcome']['name']
                except:
                    outcome = 'Complete'
    
                attributes = {
                    "match_id": match_id,
                    "team": p["possession_team"]["name"],
                    "player_from": p['player']['name'],
                    "player_to": p['pass']['recipient']['name'],
                    'location': p['location'],
                    'pass_type': p['pass']['height']['name'],
                    'outcome': outcome
                }
                
                all_events.append(attributes)
            
            except KeyError:
                next
            
    return pd.DataFrame(all_events)

# %%
competition_id = 43 # world cup 2018
season_id = 3

# %%
df = get_data(competition_id, season_id)

# %%
df.head()
# Out:
#    match_id  team                          player_from  \
# 0      7562  Peru         José Paolo Guerrero González
# 1      7562  Peru        Renato Fabrizio Tapia Cortijo
# 2      7562  Peru         Víctor Yoshimar Yotún Flores
# 3      7562  Peru  Luis Jan Piers Advíncula Castrillón
# 4      7562  Peru         Anderson Santamaría Bardales
#
#                              player_to      location    pass_type   outcome
# 0        Renato Fabrizio Tapia Cortijo  [60.0, 41.0]  Ground Pass  Complete
# 1         Víctor Yoshimar Yotún Flores  [46.0, 41.0]  Ground Pass  Complete
# 2  Luis Jan Piers Advíncula Castrillón  [40.0, 28.0]  Ground Pass  Complete
# 3         Anderson Santamaría Bardales  [43.0, 76.0]  Ground Pass  Complete
# 4         Víctor Yoshimar Yotún Flores  [38.0, 38.0]  Ground Pass  Complete

# %%
df.shape
# Out:
# (58964, 7)

# %% [markdown]
# ## __DATA CLEANING__

# %% [markdown]
# Pass Outcome: simplifying to complete/incomplete

# %%
df['outcome'].unique()
# Out:
# array(['Complete', 'Incomplete', 'Out', 'Pass Offside', 'Unknown'],
#       dtype=object)

# %%
def outcome_clean(x):
    if x == "Complete":
        outcome = x
    else:
        outcome = "Incomplete"
    return outcome

# %%
df['outcome_c'] = df['outcome'].apply(outcome_clean)

# %%
df.head()
# Out:
#    match_id  team                          player_from  \
# 0      7562  Peru         José Paolo Guerrero González
# 1      7562  Peru        Renato Fabrizio Tapia Cortijo
# 2      7562  Peru         Víctor Yoshimar Yotún Flores
# 3      7562  Peru  Luis Jan Piers Advíncula Castrillón
# 4      7562  Peru         Anderson Santamaría Bardales
#
#                              player_to      location    pass_type   outcome  \
# 0        Renato Fabrizio Tapia Cortijo  [60.0, 41.0]  Ground Pass  Complete
# 1         Víctor Yoshimar Yotún Flores  [46.0, 41.0]  Ground Pass  Complete
# 2  Luis Jan Piers Advíncula Castrillón  [40.0, 28.0]  Ground Pass  Complete
# 3         Anderson Santamaría Bardales  [43.0, 76.0]  Ground Pass  Complete
# 4         Víctor Yoshimar Yotún Flores  [38.0, 38.0]  Ground Pass  Complete
#
#   outcome_c
# 0  Complete
# 1  Complete
# 2  Complete
# 3  Complete
# 4  Complete

# %%
df['outcome_c'].unique()
# Out:
# array(['Complete', 'Incomplete'], dtype=object)

# %% [markdown]
# X/Y Location: Parsing the location into separate x, y columns

# %%
def location_x(a):
    x = a[0]
    return x

def location_y(a):
    y = a[1]
    return y

# %%
df['location_x'] = df["location"].apply(location_x)
df['location_y'] = df["location"].apply(location_y)

# %%
df.head()
# Out:
#    match_id  team                          player_from  \
# 0      7562  Peru         José Paolo Guerrero González
# 1      7562  Peru        Renato Fabrizio Tapia Cortijo
# 2      7562  Peru         Víctor Yoshimar Yotún Flores
# 3      7562  Peru  Luis Jan Piers Advíncula Castrillón
# 4      7562  Peru         Anderson Santamaría Bardales
#
#                              player_to      location    pass_type   outcome  \
# 0        Renato Fabrizio Tapia Cortijo  [60.0, 41.0]  Ground Pass  Complete
# 1         Víctor Yoshimar Yotún Flores  [46.0, 41.0]  Ground Pass  Complete
# 2  Luis Jan Piers Advíncula Castrillón  [40.0, 28.0]  Ground Pass  Complete
# 3         Anderson Santamaría Bardales  [43.0, 76.0]  Ground Pass  Complete
# 4         Víctor Yoshimar Yotún Flores  [38.0, 38.0]  Ground Pass  Complete
#
#   outcome_c  location_x  location_y
# 0  Complete        60.0        41.0
# 1  Complete        46.0        41.0
# 2  Complete        40.0        28.0
# 3  Complete        43.0        76.0
# 4  Complete        38.0        38.0

# %% [markdown]
# ## __GRAPH PREPARATION__

# %% [markdown]
# ### __Node Table__
# - Node ID
# - Degree Centrality
# - X Position
# - Y Position
# - Player Name
# - Number of Pass Attempts
#     - By type?
# - Completion Percentage
#     - By type?

# %% [markdown]
# Filtering the passing data for only passes between France teammates:

# %%
FR_players = list(pd.DataFrame({'passes':df.query("team=='France'").query("outcome_c=='Complete'").groupby(['player_from']).size()}).sort_values(by='passes', ascending=False).head(20).index.values)
df_FR = df[df['player_from'].isin(FR_players) & df['player_to'].isin(FR_players)]
df_FR.head(3)
# Out:
#        match_id    team        player_from             player_to  \
# 12101      8655  France  Antoine Griezmann        Raphaël Varane
# 12102      8655  France     Raphaël Varane       Benjamin Pavard
# 12103      8655  France    Benjamin Pavard  Kylian Mbappé Lottin
#
#            location    pass_type   outcome outcome_c  location_x  location_y
# 12101  [60.0, 41.0]  Ground Pass  Complete  Complete        60.0        41.0
# 12102  [38.0, 50.0]  Ground Pass  Complete  Complete        38.0        50.0
# 12103  [50.0, 72.0]  Ground Pass  Complete  Complete        50.0        72.0

# %% [markdown]
# Filtering only for the World Cup Final

# %%
df_FR = df_FR.query("match_id == 8658")
df_FR.head()
# Out:
#        match_id    team        player_from             player_to  \
# 45314      8658  France    Benjamin Pavard          N"Golo Kanté
# 45315      8658  France       N"Golo Kanté            Paul Pogba
# 45318      8658  France  Antoine Griezmann  Kylian Mbappé Lottin
# 45319      8658  France    Benjamin Pavard        Raphaël Varane
# 45320      8658  France     Raphaël Varane           Hugo Lloris
#
#            location    pass_type     outcome   outcome_c  location_x  \
# 45314  [49.0, 80.0]     Low Pass    Complete    Complete        49.0
# 45315  [65.0, 64.0]    High Pass  Incomplete  Incomplete        65.0
# 45318  [63.0, 73.0]  Ground Pass    Complete    Complete        63.0
# 45319  [58.0, 79.0]     Low Pass    Complete    Complete        58.0
# 45320  [26.0, 69.0]  Ground Pass    Complete    Complete        26.0
#
#        location_y
# 45314        80.0
# 45315        64.0
# 45318        73.0
# 45319        79.0
# 45320        69.0

# %% [markdown]
# Assemble the node table

# %%
dict_FR = {
    'id': ['n{}'.format(i) for i in range(1,len(df_FR['player_from'].unique())+1)],
    'x_pos_abs': df_FR[['player_from','location_x']].groupby(['player_from']).mean()['location_x'],                              
    'y_pos_abs': df_FR[['player_from','location_y']].groupby(['player_from']).mean()['location_y'],                              
    'x_pos_perc': df_FR[['player_from','location_x']].groupby(['player_from']).mean()['location_x']/120, # x position as a proportion of pitch length
    'y_pos_perc': df_FR[['player_from','location_y']].groupby(['player_from']).mean()['location_y']/80, # y position as a proportion of pitch width
    'name': sorted(df_FR['player_from'].unique()),
    'centrality': df_FR.groupby(['player_from']).size().values / df_FR.groupby(['player_from']).size().values.sum() / (df_FR.groupby(['player_from']).size().values / df_FR.groupby(['player_from']).size().values.sum()).max(),
    'pass_attempts': df_FR.groupby(['player_from']).size().values,
    'pass_completed': df_FR.query("outcome_c=='Complete'").groupby(['player_from']).size().values,
    'comp_percentage': df_FR.query("outcome_c=='Complete'").groupby(['player_from']).size().values / df_FR.groupby(['player_from']).size().values,
}

node_FR = pd.DataFrame(dict_FR)

node_FR
# Out:
#                                              id  x_pos_abs  y_pos_abs  \
# player_from
# Antoine Griezmann                            n1  68.727273  37.363636
# Benjamin Pavard                              n2  60.523810  75.809524
# Blaise Matuidi                               n3  52.450000  15.300000
# Corentin Tolisso                             n4  76.500000  23.750000
# Hugo Lloris                                  n5  11.833333  40.166667
# Kylian Mbappé Lottin                         n6  76.545455  63.818182
# Lucas Hernández Pi                           n7  54.555556   5.962963
# N"Golo Kanté                                 n8  38.100000  20.400000
# Nabil Fekir                                  n9  72.500000  67.500000
# Olivier Giroud                              n10  66.444444  43.666667
# Paul Pogba                                  n11  51.312500  46.468750
# Raphaël Varane                              n12  45.500000  57.444444
# Samuel Yves Umtiti                          n13  42.947368  21.684211
# Steven N"Kemboanza Mike Christopher Nzonzi  n14  50.785714  37.500000
#
#                                             x_pos_perc  y_pos_perc  \
# player_from
# Antoine Griezmann                             0.572727    0.467045
# Benjamin Pavard                               0.504365    0.947619
# Blaise Matuidi                                0.437083    0.191250
# Corentin Tolisso                              0.637500    0.296875
# Hugo Lloris                                   0.098611    0.502083
# Kylian Mbappé Lottin                          0.637879    0.797727
# Lucas Hernández Pi                            0.454630    0.074537
# N"Golo Kanté                                  0.317500    0.255000
# Nabil Fekir                                   0.604167    0.843750
# Olivier Giroud                                0.553704    0.545833
# Paul Pogba                                    0.427604    0.580859
# Raphaël Varane                                0.379167    0.718056
# Samuel Yves Umtiti                            0.357895    0.271053
# Steven N"Kemboanza Mike Christopher Nzonzi    0.423214    0.468750
#
#                                                                                   name  \
# player_from
# Antoine Griezmann                                                    Antoine Griezmann
# Benjamin Pavard                                                        Benjamin Pavard
# Blaise Matuidi                                                          Blaise Matuidi
# Corentin Tolisso                                                      Corentin Tolisso
# Hugo Lloris                                                                Hugo Lloris
# Kylian Mbappé Lottin                                              Kylian Mbappé Lottin
# Lucas Hernández Pi                                                  Lucas Hernández Pi
# N"Golo Kanté                                                              N"Golo Kanté
# Nabil Fekir                                                                Nabil Fekir
# Olivier Giroud                                                          Olivier Giroud
# Paul Pogba                                                                  Paul Pogba
# Raphaël Varane                                                          Raphaël Varane
# Samuel Yves Umtiti                                                  Samuel Yves Umtiti
# Steven N"Kemboanza Mike Christopher Nzonzi  Steven N"Kemboanza Mike Christopher Nzonzi
#
#                                             centrality  pass_attempts  \
# player_from
# Antoine Griezmann                              0.68750             22
# Benjamin Pavard                                0.65625             21
# Blaise Matuidi                                 0.62500             20
# Corentin Tolisso                               0.12500              4
# Hugo Lloris                                    0.56250             18
# Kylian Mbappé Lottin                           0.34375             11
# Lucas Hernández Pi                             0.84375             27
# N"Golo Kanté                                   0.31250             10
# Nabil Fekir                                    0.06250              2
# Olivier Giroud                                 0.56250             18
# Paul Pogba                                     1.00000             32
# Raphaël Varane                                 0.56250             18
# Samuel Yves Umtiti                             0.59375             19
# Steven N"Kemboanza Mike Christopher Nzonzi     0.43750             14
#
#                                             pass_completed  comp_percentage
# player_from
# Antoine Griezmann                                       18         0.818182
# Benjamin Pavard                                         17         0.809524
# Blaise Matuidi                                          18         0.900000
# Corentin Tolisso                                         3         0.750000
# Hugo Lloris                                             16         0.888889
# Kylian Mbappé Lottin                                     8         0.727273
# Lucas Hernández Pi                                      22         0.814815
# N"Golo Kanté                                             7         0.700000
# Nabil Fekir                                              1         0.500000
# Olivier Giroud                                          14         0.777778
# Paul Pogba                                              29         0.906250
# Raphaël Varane                                          18         1.000000
# Samuel Yves Umtiti                                      17         0.894737
# Steven N"Kemboanza Mike Christopher Nzonzi              14         1.000000

# %%
node_FR.to_csv("player_nodes.csv", index=False)

# %% [markdown]
# ### __Directed Link Table__
# - Player 1
# - Player 2
# - Num Completed Passes (Link Weight)
# - Completion Percentage
# - Num Completed Passes 1->2

# %%
query_c = df_FR.query("outcome_c=='Complete'").groupby(['player_from','player_to'], as_index=False).size()

# %%
query_c
# Out:
# player_from                                 player_to
# Antoine Griezmann                           Benjamin Pavard         1
#                                             Blaise Matuidi          2
#                                             Corentin Tolisso        3
#                                             Kylian Mbappé Lottin    2
#                                             Lucas Hernández Pi      2
#                                                                    ..
# Steven N"Kemboanza Mike Christopher Nzonzi  Lucas Hernández Pi      1
#                                             Nabil Fekir             1
#                                             Paul Pogba              3
#                                             Raphaël Varane          1
#                                             Samuel Yves Umtiti      1
# Length: 96, dtype: int64

# %% [markdown]
# Assemble the majority of the links table

# %%
links_FR = pd.DataFrame()
for i in range(query_c.shape[0]):
    row_Dict = {
    'id': 'l{}'.format(i+1),
    'source': query_c.index[i][0],
    'source_x': node_FR.loc[query_c.index[i][0],'x_pos_perc'],
    'source_y': node_FR.loc[query_c.index[i][0],'y_pos_perc'],
    'target': query_c.index[i][1],
    'target_x': node_FR.loc[query_c.index[i][1],'x_pos_perc'],
    'target_y': node_FR.loc[query_c.index[i][1],'y_pos_perc'],
    'pass_completed': query_c[i]
    }
    links_FR = links_FR.append(row_Dict, ignore_index=True)

# %%
links_FR
# Out:
#      id  pass_completed                                      source  source_x  \
# 0    l1             1.0                           Antoine Griezmann  0.572727
# 1    l2             2.0                           Antoine Griezmann  0.572727
# 2    l3             3.0                           Antoine Griezmann  0.572727
# 3    l4             2.0                           Antoine Griezmann  0.572727
# 4    l5             2.0                           Antoine Griezmann  0.572727
# ..  ...             ...                                         ...       ...
# 91  l92             1.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
# 92  l93             1.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
# 93  l94             3.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
# 94  l95             1.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
# 95  l96             1.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
#
#     source_y                target  target_x  target_y
# 0   0.467045       Benjamin Pavard  0.504365  0.947619
# 1   0.467045        Blaise Matuidi  0.437083  0.191250
# 2   0.467045      Corentin Tolisso  0.637500  0.296875
# 3   0.467045  Kylian Mbappé Lottin  0.637879  0.797727
# 4   0.467045    Lucas Hernández Pi  0.454630  0.074537
# ..       ...                   ...       ...       ...
# 91  0.468750    Lucas Hernández Pi  0.454630  0.074537
# 92  0.468750           Nabil Fekir  0.604167  0.843750
# 93  0.468750            Paul Pogba  0.427604  0.580859
# 94  0.468750        Raphaël Varane  0.379167  0.718056
# 95  0.468750    Samuel Yves Umtiti  0.357895  0.271053
#
# [96 rows x 8 columns]

# %% [markdown]
# Add pass attempts to the links table

# %%
query_a = df_FR.groupby(['player_from','player_to'], as_index=False).size()
query_a
# Out:
# player_from                                 player_to
# Antoine Griezmann                           Benjamin Pavard         1
#                                             Blaise Matuidi          4
#                                             Corentin Tolisso        3
#                                             Kylian Mbappé Lottin    3
#                                             Lucas Hernández Pi      3
#                                                                    ..
# Steven N"Kemboanza Mike Christopher Nzonzi  Lucas Hernández Pi      1
#                                             Nabil Fekir             1
#                                             Paul Pogba              3
#                                             Raphaël Varane          1
#                                             Samuel Yves Umtiti      1
# Length: 102, dtype: int64

# %%
att_FR = pd.DataFrame()
for i in range(query_a.shape[0]):
    row_Dict = {
    'source': query_a.index[i][0],
    'target': query_a.index[i][1],
    'pass_attempts': query_a[i]
    }
    att_FR = att_FR.append(row_Dict, ignore_index=True)

att_FR
# Out:
#      pass_attempts                                      source  \
# 0              1.0                           Antoine Griezmann
# 1              4.0                           Antoine Griezmann
# 2              3.0                           Antoine Griezmann
# 3              3.0                           Antoine Griezmann
# 4              3.0                           Antoine Griezmann
# ..             ...                                         ...
# 97             1.0  Steven N"Kemboanza Mike Christopher Nzonzi
# 98             1.0  Steven N"Kemboanza Mike Christopher Nzonzi
# 99             3.0  Steven N"Kemboanza Mike Christopher Nzonzi
# 100            1.0  Steven N"Kemboanza Mike Christopher Nzonzi
# 101            1.0  Steven N"Kemboanza Mike Christopher Nzonzi
#
#                    target
# 0         Benjamin Pavard
# 1          Blaise Matuidi
# 2        Corentin Tolisso
# 3    Kylian Mbappé Lottin
# 4      Lucas Hernández Pi
# ..                    ...
# 97     Lucas Hernández Pi
# 98            Nabil Fekir
# 99             Paul Pogba
# 100        Raphaël Varane
# 101    Samuel Yves Umtiti
#
# [102 rows x 3 columns]

# %%
links_FR = links_FR.merge(att_FR,how='left', on=['source','target'])
links_FR['comp_percentage'] = links_FR['pass_completed'] / links_FR['pass_attempts']
links_FR
# Out:
#      id  pass_completed                                      source  source_x  \
# 0    l1             1.0                           Antoine Griezmann  0.572727
# 1    l2             2.0                           Antoine Griezmann  0.572727
# 2    l3             3.0                           Antoine Griezmann  0.572727
# 3    l4             2.0                           Antoine Griezmann  0.572727
# 4    l5             2.0                           Antoine Griezmann  0.572727
# ..  ...             ...                                         ...       ...
# 91  l92             1.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
# 92  l93             1.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
# 93  l94             3.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
# 94  l95             1.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
# 95  l96             1.0  Steven N"Kemboanza Mike Christopher Nzonzi  0.423214
#
#     source_y                target  target_x  target_y  pass_attempts  \
# 0   0.467045       Benjamin Pavard  0.504365  0.947619            1.0
# 1   0.467045        Blaise Matuidi  0.437083  0.191250            4.0
# 2   0.467045      Corentin Tolisso  0.637500  0.296875            3.0
# 3   0.467045  Kylian Mbappé Lottin  0.637879  0.797727            3.0
# 4   0.467045    Lucas Hernández Pi  0.454630  0.074537            3.0
# ..       ...                   ...       ...       ...            ...
# 91  0.468750    Lucas Hernández Pi  0.454630  0.074537            1.0
# 92  0.468750           Nabil Fekir  0.604167  0.843750            1.0
# 93  0.468750            Paul Pogba  0.427604  0.580859            3.0
# 94  0.468750        Raphaël Varane  0.379167  0.718056            1.0
# 95  0.468750    Samuel Yves Umtiti  0.357895  0.271053            1.0
#
#     comp_percentage
# 0          1.000000
# 1          0.500000
# 2          1.000000
# 3          0.666667
# 4          0.666667
# ..              ...
# 91         1.000000
# 92         1.000000
# 93         1.000000
# 94         1.000000
# 95         1.000000
#
# [96 rows x 10 columns]

# %%
links_FR.to_csv('player_links.csv', index=False)
